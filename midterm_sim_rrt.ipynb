# %% [markdown]
# # RRT Sampling-Based Motion Planning

# %%
# The autoreload extension will automatically load in new code as you edit files, 
# so you don't need to restart the kernel every time
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from P4_rrt import *

plt.rcParams['figure.figsize'] = [8, 8] # Change default figure size

# %% [markdown]
# ### Set up workspace

# %%
mazeCloud = np.load(r"C:\Users\user\OneDrive - Stanford\Documents\Stanford\AA274A - Principles of Robot Autonomy I\midterm\maze_wall_map_cluster.npy")
mazeBackground = plt.imread(r"C:\Users\user\OneDrive - Stanford\Documents\Stanford\AA274A - Principles of Robot Autonomy I\midterm\cluster.png")

x_init = [10,20,np.pi/4]
x_goal = [100,90,np.pi/6]

# %% [markdown]
# ## Geometric Planning

# %%
grrt = MidtermRRT([0,0,-np.pi/2], [120,120,np.pi/2], x_init, x_goal, mazeCloud,20.0,10.0, mazeBackground)
grrt.solve(10.0, 2000)
# Out:
# True

# %% [markdown]
# ### Set up workspace

# %%
mazeCloud = np.load(r"C:\Users\user\OneDrive - Stanford\Documents\Stanford\AA274A - Principles of Robot Autonomy I\midterm\maze_wall_map_gap.npy")
mazeBackground = plt.imread(r"C:\Users\user\OneDrive - Stanford\Documents\Stanford\AA274A - Principles of Robot Autonomy I\midterm\gap.png")

x_init = [20,30,-np.pi/6]
x_goal = [90,25,0.]

# %% [markdown]
# ## Geometric Planning

# %%
grrt = MidtermRRT([0,0,-np.pi/2], [120,120,np.pi/2], x_init, x_goal, mazeCloud,10.0,5.0, mazeBackground)
grrt.solve(5.0, 2000)
# Out:
# True

# %% [markdown]
# ### Set up workspace

# %%
plt.rcParams['figure.figsize'] = [20, 8] # Change default figure size

mazeCloud = np.load(r"C:\Users\user\OneDrive - Stanford\Documents\Stanford\AA274A - Principles of Robot Autonomy I\midterm\maze_wall_map_43abridged.npy")
mazeBackground = plt.imread(r"C:\Users\user\OneDrive - Stanford\Documents\Stanford\AA274A - Principles of Robot Autonomy I\midterm\4-3c_abridged.png")

x_init = [183,37,0.]
x_goal = [545,59,0.]

# %% [markdown]
# ## Geometric Planning

# %%
grrt = MidtermRRT([0,0,-np.pi/2], [1243,130,np.pi/2], x_init, x_goal, mazeCloud,15.0,12.0, mazeBackground)
grrt.solve(10.0, 2000)
# Out:
# True
